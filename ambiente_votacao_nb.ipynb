# %% [markdown]
# # Análise de Votação com Naive Bayes
# Este notebook contém uma análise de dados de votação usando diferentes implementações do Naive Bayes.
#
# ## Configuração do Ambiente
# Antes de executar este notebook, certifique-se de ter todas as dependências instaladas.
#
# ### Requisitos
# - Python 3.8+
# - pip (gerenciador de pacotes Python)
#
# ### Instalação das Dependências
# Execute a célula abaixo para instalar todas as bibliotecas necessárias:

# %%
# !pip install pandas numpy matplotlib seaborn scikit-learn ipython

# %% [markdown]
# ## Verificação do Ambiente
# Vamos verificar se todas as bibliotecas foram instaladas corretamente:

# %%
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.impute import SimpleImputer
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB

print("Python version:", sys.version)
print("\nVersões das bibliotecas:")
print("pandas:", pd.__version__)
print("numpy:", np.__version__)
print("matplotlib:", plt.__version__)
print("seaborn:", sns.__version__)
print("scikit-learn:", sklearn.__version__)

# %% [markdown]
# ## Configuração do Matplotlib
# Configurando o estilo dos gráficos para melhor visualização:

# %%
# Configuração para melhor visualização dos gráficos
plt.style.use('seaborn')
# Aumentar o tamanho padrão das figuras
plt.rcParams['figure.figsize'] = [10, 6]
# Aumentar o tamanho das fontes
plt.rcParams['font.size'] = 12
# Configurar para exibir gráficos no notebook
# %matplotlib inline

# %% [markdown]
# ## Pronto para Começar!
# Agora o ambiente está configurado e você pode começar a análise.
#
# **Importante:**
# 1. Execute todas as células acima antes de prosseguir com a análise
# 2. Caso encontre algum erro na instalação das bibliotecas:
#    - Tente reiniciar o kernel do notebook
#    - Verifique se o Python está corretamente instalado
#    - Em caso de problemas com permissões, tente executar o pip com privilégios de administrador
#
# ## Próximos Passos
# Você pode agora copiar e colar o código da sua análise a partir deste ponto.
